# %%
# 1. Importing the library
from sklearn import tree
import pandas as pd
import seaborn as sns # creating box plot - find out any outliers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
# 2. Dataset
# Input variables with three features (Height, Weight, Shoe Size)
raw_data = pd.read_excel('../Data/gender_classification_data.xlsx')

# %%
raw_data.head()
# Out:
#    Height  Weight  Shoe_Size  Height Inches  Gender
# 0     180    80.0       44.0        70.8660    Male
# 1     178    78.0       42.0        70.0786    Male
# 2     160    60.0       38.0        62.9920    Male
# 3     140    50.0       34.0        55.1180  Female
# 4     130    45.0        NaN        51.1810  Female

# %%
# Handling the missing values
missing_data = raw_data[raw_data.isnull().any(axis=1)]
print(missing_data)
# Out:
#     Height  Weight  Shoe_Size  Height Inches  Gender
# 4      130    45.0        NaN        51.1810  Female
# 14     146     NaN       32.0        57.4802  Female
# 18     180    78.0        NaN        70.8660    Male
# 37     178     NaN       42.0        70.0786    Male

# %%
raw_data.loc[raw_data['Height']==130, 'Shoe_Size']
raw_data.loc[raw_data['Weight']==45.0, 'Shoe_Size']
# Out:
# 4    35.0
# Name: Shoe_Size, dtype: float64

# %%
raw_data.loc[raw_data['Gender']=='Female', 'Shoe_Size'].mean()
raw_data.iloc[4:5, 2:3] = raw_data.iloc[4:5, 2:3].fillna(35)

# %%
raw_data.loc[raw_data['Height']==146, 'Weight']
raw_data.iloc[14:15, 1:2] = raw_data.iloc[14:15, 1:2].fillna(50)

# %%
raw_data.loc[raw_data['Height']==180, 'Shoe_Size'].mean()
raw_data.iloc[18:19, 2:3] = raw_data.iloc[18:19, 2:3].fillna(42)
# Out:
# 42.30769230769231

# %%
#raw_data.loc[raw_data['Height']==178, 'Weight'].mean()
raw_data.iloc[37:38, 1:2] = raw_data.iloc[37:38, 1:2].fillna(78)

# %%
raw_data
# Out:
#     Height  Weight  Shoe_Size  Height Inches  Gender
# 0      180    80.0       44.0        70.8660    Male
# 1      178    78.0       42.0        70.0786    Male
# 2      160    60.0       38.0        62.9920    Male
# 3      140    50.0       34.0        55.1180  Female
# 4      130    45.0      135.0        51.1810  Female
# 5      144    50.0       38.0        56.6928  Female
# 6      134    52.0       36.0        52.7558  Female
# 7      188    84.0       44.0        74.0156    Male
# 8      190    88.0       44.0        74.8030    Male
# 9      178    78.0       42.0        70.0786    Male
# 10     172    74.0       46.0        67.7164    Male
# 11     164    68.0       40.0        64.5668    Male
# 12     154    58.0       34.0        60.6298  Female
# 13     168    70.0       40.0        66.1416    Male
# 14     146    50.0       32.0        57.4802  Female
# 15     180    82.0       42.0        70.8660    Male
# 16     182    84.0       44.0        71.6534    Male
# 17     110    50.0       38.0        43.3070    Male
# 18     180    78.0       42.0        70.8660    Male
# 19     146    50.0       32.0        57.4802  Female
# 20     180    82.0       42.0        70.8660    Male
# 21     182    84.0       44.0        71.6534    Male
# 22     134    52.0       36.0        52.7558  Female
# 23     188    84.0       44.0        74.0156    Male
# 24     190    88.0       44.0        74.8030    Male
# 25     178    78.0       42.0        70.0786    Male
# 26     172    74.0       46.0        67.7164    Male
# 27     110    50.0       38.0        43.3070    Male
# 28     180    78.0       42.0        70.8660    Male
# 29     146    50.0       32.0        57.4802  Female
# ..     ...     ...        ...            ...     ...
# 70     188    84.0       44.0        74.0156  Female
# 71     134    52.0       36.0        52.7558    Male
# 72     100    30.0       30.0        39.3700  Female
# 73     220   140.0       50.0        86.6140    Male
# 74     182    84.0       44.0        71.6534    Male
# 75     134    52.0       36.0        52.7558  Female
# 76     188    84.0       44.0        74.0156    Male
# 77     190    88.0       44.0        74.8030    Male
# 78     178    78.0       42.0        70.0786    Male
# 79     172    74.0       46.0        67.7164    Male
# 80     110    50.0       38.0        43.3070    Male
# 81     134    52.0       36.0        52.7558  Female
# 82     188    84.0       44.0        74.0156    Male
# 83     190    88.0       44.0        74.8030    Male
# 84     178    78.0       42.0        70.0786    Male
# 85     172    74.0       46.0        67.7164    Male
# 86     134    52.0       36.0        52.7558  Female
# 87     188    84.0       44.0        74.0156    Male
# 88     190    88.0       44.0        74.8030    Male
# 89     180    80.0       44.0        70.8660    Male
# 90     178    78.0       42.0        70.0786    Male
# 91     160    60.0       38.0        62.9920    Male
# 92     140    50.0       34.0        55.1180  Female
# 93     180    82.0       42.0        70.8660    Male
# 94     182    84.0       44.0        71.6534    Male
# 95     134    52.0       36.0        52.7558  Female
# 96     188    84.0       44.0        74.0156    Male
# 97     134    52.0       36.0        52.7558  Female
# 98     188    84.0       44.0        74.0156    Male
# 99     178    78.0       42.0        70.0786    Male
#
# [100 rows x 5 columns]

# %%
# Outliers
sns.boxplot(data=raw_data, orient='v')

# %%
#raw_data.loc[raw_data['Weight']>125, 'Weight']
raw_data.drop(raw_data.index[73])
# Out:
#     Height  Weight  Shoe_Size  Height Inches  Gender
# 0      180    80.0       44.0        70.8660    Male
# 1      178    78.0       42.0        70.0786    Male
# 2      160    60.0       38.0        62.9920    Male
# 3      140    50.0       34.0        55.1180  Female
# 4      130    45.0      135.0        51.1810  Female
# 5      144    50.0       38.0        56.6928  Female
# 6      134    52.0       36.0        52.7558  Female
# 7      188    84.0       44.0        74.0156    Male
# 8      190    88.0       44.0        74.8030    Male
# 9      178    78.0       42.0        70.0786    Male
# 10     172    74.0       46.0        67.7164    Male
# 11     164    68.0       40.0        64.5668    Male
# 12     154    58.0       34.0        60.6298  Female
# 13     168    70.0       40.0        66.1416    Male
# 14     146    50.0       32.0        57.4802  Female
# 15     180    82.0       42.0        70.8660    Male
# 16     182    84.0       44.0        71.6534    Male
# 17     110    50.0       38.0        43.3070    Male
# 18     180    78.0       42.0        70.8660    Male
# 19     146    50.0       32.0        57.4802  Female
# 20     180    82.0       42.0        70.8660    Male
# 21     182    84.0       44.0        71.6534    Male
# 22     134    52.0       36.0        52.7558  Female
# 23     188    84.0       44.0        74.0156    Male
# 24     190    88.0       44.0        74.8030    Male
# 25     178    78.0       42.0        70.0786    Male
# 26     172    74.0       46.0        67.7164    Male
# 27     110    50.0       38.0        43.3070    Male
# 28     180    78.0       42.0        70.8660    Male
# 29     146    50.0       32.0        57.4802  Female
# ..     ...     ...        ...            ...     ...
# 69     134    52.0       36.0        52.7558  Female
# 70     188    84.0       44.0        74.0156  Female
# 71     134    52.0       36.0        52.7558    Male
# 72     100    30.0       30.0        39.3700  Female
# 74     182    84.0       44.0        71.6534    Male
# 75     134    52.0       36.0        52.7558  Female
# 76     188    84.0       44.0        74.0156    Male
# 77     190    88.0       44.0        74.8030    Male
# 78     178    78.0       42.0        70.0786    Male
# 79     172    74.0       46.0        67.7164    Male
# 80     110    50.0       38.0        43.3070    Male
# 81     134    52.0       36.0        52.7558  Female
# 82     188    84.0       44.0        74.0156    Male
# 83     190    88.0       44.0        74.8030    Male
# 84     178    78.0       42.0        70.0786    Male
# 85     172    74.0       46.0        67.7164    Male
# 86     134    52.0       36.0        52.7558  Female
# 87     188    84.0       44.0        74.0156    Male
# 88     190    88.0       44.0        74.8030    Male
# 89     180    80.0       44.0        70.8660    Male
# 90     178    78.0       42.0        70.0786    Male
# 91     160    60.0       38.0        62.9920    Male
# 92     140    50.0       34.0        55.1180  Female
# 93     180    82.0       42.0        70.8660    Male
# 94     182    84.0       44.0        71.6534    Male
# 95     134    52.0       36.0        52.7558  Female
# 96     188    84.0       44.0        74.0156    Male
# 97     134    52.0       36.0        52.7558  Female
# 98     188    84.0       44.0        74.0156    Male
# 99     178    78.0       42.0        70.0786    Male
#
# [99 rows x 5 columns]

# %%
# Dropping redundant column
raw_data.drop(['Height Inches'], axis = 1)
# Out:
#     Height  Weight  Shoe_Size  Gender
# 0      180    80.0       44.0    Male
# 1      178    78.0       42.0    Male
# 2      160    60.0       38.0    Male
# 3      140    50.0       34.0  Female
# 4      130    45.0      135.0  Female
# 5      144    50.0       38.0  Female
# 6      134    52.0       36.0  Female
# 7      188    84.0       44.0    Male
# 8      190    88.0       44.0    Male
# 9      178    78.0       42.0    Male
# 10     172    74.0       46.0    Male
# 11     164    68.0       40.0    Male
# 12     154    58.0       34.0  Female
# 13     168    70.0       40.0    Male
# 14     146    50.0       32.0  Female
# 15     180    82.0       42.0    Male
# 16     182    84.0       44.0    Male
# 17     110    50.0       38.0    Male
# 18     180    78.0       42.0    Male
# 19     146    50.0       32.0  Female
# 20     180    82.0       42.0    Male
# 21     182    84.0       44.0    Male
# 22     134    52.0       36.0  Female
# 23     188    84.0       44.0    Male
# 24     190    88.0       44.0    Male
# 25     178    78.0       42.0    Male
# 26     172    74.0       46.0    Male
# 27     110    50.0       38.0    Male
# 28     180    78.0       42.0    Male
# 29     146    50.0       32.0  Female
# ..     ...     ...        ...     ...
# 70     188    84.0       44.0  Female
# 71     134    52.0       36.0    Male
# 72     100    30.0       30.0  Female
# 73     220   140.0       50.0    Male
# 74     182    84.0       44.0    Male
# 75     134    52.0       36.0  Female
# 76     188    84.0       44.0    Male
# 77     190    88.0       44.0    Male
# 78     178    78.0       42.0    Male
# 79     172    74.0       46.0    Male
# 80     110    50.0       38.0    Male
# 81     134    52.0       36.0  Female
# 82     188    84.0       44.0    Male
# 83     190    88.0       44.0    Male
# 84     178    78.0       42.0    Male
# 85     172    74.0       46.0    Male
# 86     134    52.0       36.0  Female
# 87     188    84.0       44.0    Male
# 88     190    88.0       44.0    Male
# 89     180    80.0       44.0    Male
# 90     178    78.0       42.0    Male
# 91     160    60.0       38.0    Male
# 92     140    50.0       34.0  Female
# 93     180    82.0       42.0    Male
# 94     182    84.0       44.0    Male
# 95     134    52.0       36.0  Female
# 96     188    84.0       44.0    Male
# 97     134    52.0       36.0  Female
# 98     188    84.0       44.0    Male
# 99     178    78.0       42.0    Male
#
# [100 rows x 4 columns]

# %%
train, test = train_test_split(raw_data, test_size = 0.2)
print("Training size: {}, Test Size {}".format(len(train), len(test)))
# Out:
# Training size: 80, Test Size 20

# %%
features = ['Height', 'Weight', 'Shoe_Size']
X_train = train[features]
y_train = train['Gender']

X_test = test[features]
y_test = test['Gender'] # actual values from 8 rows of test

# %%
# Creating the model
clf = tree.DecisionTreeClassifier()

# %%
# Training the model
clf = clf.fit(X_train, y_train)

# %%
# Predict based on a new set of input variables
y_pred = clf.predict(X_test)  # predicted vaues of 8 rows

# %%
print(y_pred)
# Out:
# ['Female' 'Female' 'Female' 'Male' 'Male' 'Male' 'Male' 'Male']

# %%
score = accuracy_score(y_test, y_pred) * 100

# %%
print("Accuracy using Decision Tree: ", score, "%")
# Out:
# Accuracy using Decision Tree:  100.0 %
